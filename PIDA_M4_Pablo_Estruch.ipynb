# %% [markdown]
# # **Primer Avance**

# %%
# Librerias

import numpy as np
import pandas as pd

# %%
data = pd.read_csv("data_latinoamerica.csv",sep=',')

# %%
data
# Out:
#          location_key        date country_code country_name  new_confirmed  \
# 0                  AR  2020-01-01           AR    Argentina            3.0
# 1                  AR  2020-01-02           AR    Argentina           14.0
# 2                  AR  2020-01-03           AR    Argentina            3.0
# 3                  AR  2020-01-04           AR    Argentina            7.0
# 4                  AR  2020-01-05           AR    Argentina            5.0
# ...               ...         ...          ...          ...            ...
# 12216052         VE_Z  2022-09-13           VE    Venezuela            NaN
# 12216053         VE_Z  2022-09-14           VE    Venezuela            NaN
# 12216054         VE_Z  2022-09-15           VE    Venezuela            NaN
# 12216055         VE_Z  2022-09-16           VE    Venezuela            NaN
# 12216056         VE_Z  2022-09-17           VE    Venezuela            NaN
#
#           new_deceased  cumulative_confirmed  cumulative_deceased  \
# 0                  0.0                   3.0                  0.0
# 1                  0.0                  17.0                  0.0
# 2                  0.0                  20.0                  0.0
# 3                  0.0                  27.0                  0.0
# 4                  0.0                  32.0                  0.0
# ...                ...                   ...                  ...
# 12216052           NaN                   NaN                  NaN
# 12216053           NaN                   NaN                  NaN
# 12216054           NaN                   NaN                  NaN
# 12216055           NaN                   NaN                  NaN
# 12216056           NaN                   NaN                  NaN
#
#           cumulative_vaccine_doses_administered  population  ...  \
# 0                                           NaN  44938712.0  ...
# 1                                           NaN  44938712.0  ...
# 2                                           NaN  44938712.0  ...
# 3                                           NaN  44938712.0  ...
# 4                                           NaN  44938712.0  ...
# ...                                         ...         ...  ...
# 12216052                                    NaN   1422000.0  ...
# 12216053                                    NaN   1422000.0  ...
# 12216054                                    NaN   1422000.0  ...
# 12216055                                    NaN   1422000.0  ...
# 12216056                                    NaN   1422000.0  ...
#
#           population_largest_city  area_rural_sq_km  area_urban_sq_km  \
# 0                      15057273.0         2690269.0           55032.0
# 1                      15057273.0         2690269.0           55032.0
# 2                      15057273.0         2690269.0           55032.0
# 3                      15057273.0         2690269.0           55032.0
# 4                      15057273.0         2690269.0           55032.0
# ...                           ...               ...               ...
# 12216052                      NaN               NaN               NaN
# 12216053                      NaN               NaN               NaN
# 12216054                      NaN               NaN               NaN
# 12216055                      NaN               NaN               NaN
# 12216056                      NaN               NaN               NaN
#
#           life_expectancy  adult_male_mortality_rate  \
# 0                   76.52                    147.086
# 1                   76.52                    147.086
# 2                   76.52                    147.086
# 3                   76.52                    147.086
# 4                   76.52                    147.086
# ...                   ...                        ...
# 12216052              NaN                        NaN
# 12216053              NaN                        NaN
# 12216054              NaN                        NaN
# 12216055              NaN                        NaN
# 12216056              NaN                        NaN
#
#           adult_female_mortality_rate  pollution_mortality_rate  \
# 0                              79.483                      26.6
# 1                              79.483                      26.6
# 2                              79.483                      26.6
# 3                              79.483                      26.6
# 4                              79.483                      26.6
# ...                               ...                       ...
# 12216052                          NaN                       NaN
# 12216053                          NaN                       NaN
# 12216054                          NaN                       NaN
# 12216055                          NaN                       NaN
# 12216056                          NaN                       NaN
#
#           comorbidity_mortality_rate  new_recovered  cumulative_recovered
# 0                               15.8            NaN                   NaN
# 1                               15.8            NaN                   NaN
# 2                               15.8            NaN                   NaN
# 3                               15.8            NaN                   NaN
# 4                               15.8            NaN                   NaN
# ...                              ...            ...                   ...
# 12216052                         NaN            NaN                   NaN
# 12216053                         NaN            NaN                   NaN
# 12216054                         NaN            NaN                   NaN
# 12216055                         NaN            NaN                   NaN
# 12216056                         NaN            NaN                   NaN
#
# [12216057 rows x 50 columns]

# %%
data.shape
# Out:
# (12216057, 50)

# %%
data['country_name'].unique()
# Out:
# array(['Argentina', 'Bolivia', 'Brazil', 'Chile', 'Colombia',
#        'Costa Rica', 'Cuba', 'Dominican Republic', 'Ecuador', 'Guatemala',
#        'Honduras', 'Mexico', 'Nicaragua', 'Panama', 'Peru', 'Puerto Rico',
#        'Paraguay', 'El Salvador', 'Uruguay', 'Venezuela'], dtype=object)

# %%
paises_seleccionados=['Argentina','Chile','Colombia','Mexico','Peru','Brazil']
data_latinoamerica=data[data['country_name'].isin(paises_seleccionados)]

# %%
np.shape(data_latinoamerica)
# Out:
# (11970289, 50)

# %%
data_latinoamerica_paises = data_latinoamerica[
    data_latinoamerica['location_key'].isin(['AR', 'CL', 'CO', 'MX', 'PE', 'BR'])]

# %%
data_latinoamerica_paises_Fecha=data_latinoamerica_paises[data_latinoamerica_paises['date']>'2021-01-01']

# %%
np.shape(data_latinoamerica_paises_Fecha)
# Out:
# (3744, 50)

# %%
for pais in paises_seleccionados:
    data_latinoamerica_paises_Fecha['new_confirmed']=data_latinoamerica_paises_Fecha['new_confirmed'].fillna(data_latinoamerica_paises_Fecha[data_latinoamerica_paises_Fecha['country_name']==pais]['new_confirmed'].mean())
    data_latinoamerica_paises_Fecha['new_deceased']=data_latinoamerica_paises_Fecha['new_deceased'].fillna(data_latinoamerica_paises_Fecha[data_latinoamerica_paises_Fecha['country_name']==pais]['new_deceased'].mean())
    #data_latinoamerica_paises_Fecha['new_recovered']=data_latinoamerica_paises_Fecha['new_recovered'].fillna(data_latinoamerica_paises_Fecha[data_latinoamerica_paises_Fecha['country_name']==pais]['new_recovered'].mean())
    data_latinoamerica_paises_Fecha['cumulative_confirmed']=data_latinoamerica_paises_Fecha['cumulative_confirmed'].fillna(data_latinoamerica_paises_Fecha[data_latinoamerica_paises_Fecha['country_name']==pais]['cumulative_confirmed'].mean())
    data_latinoamerica_paises_Fecha['cumulative_deceased']=data_latinoamerica_paises_Fecha['cumulative_deceased'].fillna(data_latinoamerica_paises_Fecha[data_latinoamerica_paises_Fecha['country_name']==pais]['cumulative_deceased'].mean())
    #data_latinoamerica_paises_Fecha['cumulative_recovered']=data_latinoamerica_paises_Fecha['cumulative_recovered'].fillna(data_latinoamerica_paises_Fecha[data_latinoamerica_paises_Fecha['country_name']==pais]['cumulative_recovered'].mean())
    data_latinoamerica_paises_Fecha['rainfall_mm']=data_latinoamerica_paises_Fecha['rainfall_mm'].fillna(data_latinoamerica_paises_Fecha[data_latinoamerica_paises_Fecha['country_name']==pais]['rainfall_mm'].mean())
    data_latinoamerica_paises_Fecha['relative_humidity']=data_latinoamerica_paises_Fecha['relative_humidity'].fillna(data_latinoamerica_paises_Fecha[data_latinoamerica_paises_Fecha['country_name']==pais]['relative_humidity'].mean())
    data_latinoamerica_paises_Fecha['average_temperature_celsius']=data_latinoamerica_paises_Fecha['average_temperature_celsius'].fillna(data_latinoamerica_paises_Fecha[data_latinoamerica_paises_Fecha['country_name']==pais]['average_temperature_celsius'].mean())
    data_latinoamerica_paises_Fecha['minimum_temperature_celsius']=data_latinoamerica_paises_Fecha['minimum_temperature_celsius'].fillna(data_latinoamerica_paises_Fecha[data_latinoamerica_paises_Fecha['country_name']==pais]['minimum_temperature_celsius'].mean())
    data_latinoamerica_paises_Fecha['maximum_temperature_celsius']=data_latinoamerica_paises_Fecha['maximum_temperature_celsius'].fillna(data_latinoamerica_paises_Fecha[data_latinoamerica_paises_Fecha['country_name']==pais]['maximum_temperature_celsius'].mean())


# LLENAR NaN CON EL 0
data_latinoamerica_paises_Fecha['new_recovered'] = data_latinoamerica_paises_Fecha['new_recovered'].fillna(0)
data_latinoamerica_paises_Fecha['cumulative_recovered'] = data_latinoamerica_paises_Fecha['cumulative_recovered'].fillna(0)
data_latinoamerica_paises_Fecha['cumulative_vaccine_doses_administered'] = data_latinoamerica_paises_Fecha['cumulative_vaccine_doses_administered'].fillna(0)
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_9900\2255388810.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_latinoamerica_paises_Fecha['new_confirmed']=data_latinoamerica_paises_Fecha['new_confirmed'].fillna(data_latinoamerica_paises_Fecha[data_latinoamerica_paises_Fecha['country_name']==pais]['new_confirmed'].mean())
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_9900\2255388810.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_latinoamerica_paises_Fecha['new_deceased']=data_latinoamerica_paises_Fecha['new_deceased'].fillna(data_latinoamerica_paises_Fecha[data_latinoamerica_paises_Fecha['country_name']==pais]['new_deceased'].mean())
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_9900\2255388810.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_latinoamerica_paises_Fecha['cumulative_confirmed']=data_latinoamerica_paises_Fecha['cumulative_confirmed'].fillna(data_latinoamerica_paises_Fecha[data_latinoamerica_paises_Fecha['country_name']==pais]['cumulative_confirmed'].mean())
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_9900\2255388810.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_latinoamerica_paises_Fecha['cumulative_deceased']=data_latinoamerica_paises_Fecha['cumulative_deceased'].fillna(data_latinoamerica_paises_Fecha[data_latinoamerica_paises_Fecha['country_name']==pais]['cumulative_deceased'].mean())
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_9900\2255388810.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_latinoamerica_paises_Fecha['rainfall_mm']=data_latinoamerica_paises_Fecha['rainfall_mm'].fillna(data_latinoamerica_paises_Fecha[data_latinoamerica_paises_Fecha['country_name']==pais]['rainfall_mm'].mean())
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_9900\2255388810.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_latinoamerica_paises_Fecha['relative_humidity']=data_latinoamerica_paises_Fecha['relative_humidity'].fillna(data_latinoamerica_paises_Fecha[data_latinoamerica_paises_Fecha['country_name']==pais]['relative_humidity'].mean())
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_9900\2255388810.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_latinoamerica_paises_Fecha['average_temperature_celsius']=data_latinoamerica_paises_Fecha['average_temperature_celsius'].fillna(data_latinoamerica_paises_Fecha[data_latinoamerica_paises_Fecha['country_name']==pais]['average_temperature_celsius'].mean())
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_9900\2255388810.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_latinoamerica_paises_Fecha['minimum_temperature_celsius']=data_latinoamerica_paises_Fecha['minimum_temperature_celsius'].fillna(data_latinoamerica_paises_Fecha[data_latinoamerica_paises_Fecha['country_name']==pais]['minimum_temperature_celsius'].mean())
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_9900\2255388810.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_latinoamerica_paises_Fecha['maximum_temperature_celsius']=data_latinoamerica_paises_Fecha['maximum_temperature_celsius'].fillna(data_latinoamerica_paises_Fecha[data_latinoamerica_paises_Fecha['country_name']==pais]['maximum_temperature_celsius'].mean())
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_9900\2255388810.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_latinoamerica_paises_Fecha['new_recovered'] = data_latinoamerica_paises_Fecha['new_recovered'].fillna(0)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_9900\2255388810.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_latinoamerica_paises_Fecha['cumulative_recovered'] = data_latinoamerica_paises_Fecha['cumulative_recovered'].fillna(0)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_9900\2255388810.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_latinoamerica_paises_Fecha['cumulative_vaccine_doses_administered'] = data_latinoamerica_paises_Fecha['cumulative_vaccine_doses_administered'].fillna(0)

# %%
# Guardar el DataFrame en un archivo CSV
data_latinoamerica_paises_Fecha.to_csv("DatosFinalesFiltrado.csv", index=False)

# %%
for i in data_latinoamerica_paises.columns:
    print(i)
    print(data_latinoamerica_paises[i].describe())
    print('---------------------------------')
# Out:
# location_key
# count     5946
# unique       6
# top         AR
# freq       991
# Name: location_key, dtype: object
# ---------------------------------
# date
# count           5946
# unique           991
# top       2022-09-17
# freq               6
# Name: date, dtype: object
# ---------------------------------
# country_code
# count     5946
# unique       6
# top         AR
# freq       991
# Name: country_code, dtype: object
# ---------------------------------
# country_name
# count          5946
# unique            6
# top       Argentina
# freq            991
# Name: country_name, dtype: object
# ---------------------------------
# new_confirmed
# count      5925.000000
# mean      11156.570802
# std       20629.839506
# min        -573.000000
# 25%        1125.000000
# 50%        4017.000000
# 75%       11013.000000
# max      298408.000000
# Name: new_confirmed, dtype: float64
# ---------------------------------
# new_deceased
# count     5925.000000
# mean       267.599662
# std        443.214995
# min          0.000000
# 25%         19.000000
# 50%        108.000000
# 75%        354.000000
# max      11447.000000
# Name: new_deceased, dtype: float64
# ---------------------------------
# cumulative_confirmed
# count    5.925000e+03
# mean     4.537433e+06
# std      7.030426e+06
# min      0.000000e+00
# 25%      5.901740e+05
# 50%      2.123737e+06
# 75%      4.953702e+06
# max      3.456883e+07
# Name: cumulative_confirmed, dtype: float64
# ---------------------------------
# cumulative_deceased
# count      5925.000000
# mean     133922.916624
# std      166648.107888
# min           0.000000
# 25%       19820.000000
# 50%       83596.000000
# 75%      176696.000000
# max      685203.000000
# Name: cumulative_deceased, dtype: float64
# ---------------------------------
# cumulative_vaccine_doses_administered
# count    3.173000e+03
# mean     7.722195e+07
# std      9.582103e+07
# min      1.800000e+01
# 25%      1.526598e+07
# 50%      4.203961e+07
# 75%      8.245385e+07
# max      3.478685e+08
# Name: cumulative_vaccine_doses_administered, dtype: float64
# ---------------------------------
# population
# count    5.946000e+03
# mean     7.772147e+07
# std      6.713444e+07
# min      1.757400e+07
# 25%      2.938188e+07
# 50%      4.791080e+07
# 75%      1.109920e+08
# max      2.125594e+08
# Name: population, dtype: float64
# ---------------------------------
# population_male
# count    5.946000e+03
# mean     3.787035e+07
# std      3.318329e+07
# min      8.972014e+06
# 25%      1.445076e+07
# 50%      2.225416e+07
# 75%      5.485523e+07
# max      1.044358e+08
# Name: population_male, dtype: float64
# ---------------------------------
# population_female
# count    5.946000e+03
# mean     3.927162e+07
# std      3.448236e+07
# min      8.601989e+06
# 25%      1.493113e+07
# 50%      2.324582e+07
# 75%      5.748131e+07
# max      1.081236e+08
# Name: population_female, dtype: float64
# ---------------------------------
# population_rural
# count    5.946000e+03
# mean     1.255498e+07
# std      1.008024e+07
# min      2.341903e+06
# 25%      3.599141e+06
# 50%      8.316128e+06
# 75%      2.494867e+07
# max      2.780789e+07
# Name: population_rural, dtype: float64
# ---------------------------------
# population_urban
# count    5.946000e+03
# mean     6.833931e+07
# std      5.829241e+07
# min      1.661014e+07
# 25%      2.539034e+07
# 50%      4.108344e+07
# 75%      1.026269e+08
# max      1.832416e+08
# Name: population_urban, dtype: float64
# ---------------------------------
# population_density
# count    5946.000000
# mean       34.266833
# std        16.838641
# min        16.515000
# 25%        25.431000
# 50%        25.734500
# 75%        45.861000
# max        66.325000
# Name: population_density, dtype: float64
# ---------------------------------
# human_development_index
# count    5946.000000
# mean        0.777333
# std         0.036352
# min         0.747000
# 25%         0.750000
# 50%         0.755000
# 75%         0.825000
# max         0.832000
# Name: human_development_index, dtype: float64
# ---------------------------------
# population_age_00_09
# count    5.946000e+03
# mean     1.205908e+07
# std      9.755221e+06
# min      2.428079e+06
# 25%      5.140624e+06
# 50%      7.066513e+06
# 75%      2.157586e+07
# max      2.907691e+07
# Name: population_age_00_09, dtype: float64
# ---------------------------------
# population_age_10_19
# count    5.946000e+03
# mean     1.263694e+07
# std      1.034880e+07
# min      2.493879e+06
# 25%      5.035905e+06
# 50%      7.582694e+06
# 75%      2.196605e+07
# max      3.116045e+07
# Name: population_age_10_19, dtype: float64
# ---------------------------------
# population_age_20_29
# count    5.946000e+03
# mean     1.265890e+07
# std      1.082648e+07
# min      2.995538e+06
# 25%      4.895056e+06
# 50%      7.638860e+06
# 75%      1.868045e+07
# max      3.410464e+07
# Name: population_age_20_29, dtype: float64
# ---------------------------------
# population_age_30_39
# count    5.946000e+03
# mean     1.202553e+07
# std      1.098747e+07
# min      2.945404e+06
# 25%      4.379777e+06
# 50%      6.793724e+06
# 75%      1.676378e+07
# max      3.447676e+07
# Name: population_age_30_39, dtype: float64
# ---------------------------------
# population_age_40_49
# count    5.946000e+03
# mean     9.932776e+06
# std      9.358615e+06
# min      2.578404e+06
# 25%      3.660378e+06
# 50%      5.478956e+06
# 75%      1.293796e+07
# max      2.946201e+07
# Name: population_age_40_49, dtype: float64
# ---------------------------------
# population_age_50_59
# count    5.946000e+03
# mean     7.993603e+06
# std      7.665975e+06
# min      2.352271e+06
# 25%      2.772568e+06
# 50%      4.727962e+06
# 75%      8.959656e+06
# max      2.442120e+07
# Name: population_age_50_59, dtype: float64
# ---------------------------------
# population_age_60_69
# count    5.946000e+03
# mean     5.442399e+06
# std      5.270592e+06
# min      1.791787e+06
# 25%      1.846407e+06
# 50%      3.342804e+06
# 75%      5.433731e+06
# max      1.689686e+07
# Name: population_age_60_69, dtype: float64
# ---------------------------------
# population_age_70_79
# count    5.946000e+03
# mean     2.964913e+06
# std      2.702859e+06
# min      9.931260e+05
# 25%      1.078066e+06
# 50%      1.898659e+06
# 75%      3.119417e+06
# max      8.801551e+06
# Name: population_age_70_79, dtype: float64
# ---------------------------------
# population_age_80_and_older
# count    5.946000e+03
# mean     1.451953e+06
# std      1.252107e+06
# min      5.377210e+05
# 25%      5.731030e+05
# 50%      9.698185e+05
# 75%      1.502231e+06
# max      4.159027e+06
# Name: population_age_80_and_older, dtype: float64
# ---------------------------------
# gdp_usd
# count    5.946000e+03
# mean     7.301129e+11
# std      6.066557e+11
# min      2.268481e+11
# 25%      2.823182e+11
# 50%      3.867331e+11
# 75%      1.258287e+12
# max      1.839758e+12
# Name: gdp_usd, dtype: float64
# ---------------------------------
# gdp_per_capita_usd
# count     5946.000000
# mean      9481.833333
# std       2765.911621
# min       6432.000000
# 25%       6977.000000
# 50%       9290.000000
# 75%      10006.000000
# max      14896.000000
# Name: gdp_per_capita_usd, dtype: float64
# ---------------------------------
# latitude
# count    5946.000000
# mean      -10.566667
# std        20.020147
# min       -34.000000
# 25%       -33.000000
# 50%       -11.700000
# 75%         4.000000
# max        23.000000
# Name: latitude, dtype: float64
# ---------------------------------
# longitude
# count    5946.000000
# mean      -73.208333
# std        14.916583
# min      -102.000000
# 25%       -76.000000
# 50%       -72.125000
# 75%       -64.000000
# max       -53.000000
# Name: longitude, dtype: float64
# ---------------------------------
# area_sq_km
# count    5.946000e+03
# mean     2.740702e+06
# std      2.663775e+06
# min      7.567000e+05
# 25%      1.141748e+06
# 50%      1.624798e+06
# 75%      2.780400e+06
# max      8.515770e+06
# Name: area_sq_km, dtype: float64
# ---------------------------------
# smoking_prevalence
# count    5946.000000
# mean       16.883333
# std        10.701744
# min         4.800000
# 25%         9.000000
# 50%        13.950000
# 75%        21.800000
# max        37.800000
# Name: smoking_prevalence, dtype: float64
# ---------------------------------
# diabetes_prevalence
# count    5946.000000
# mean        8.733333
# std         2.578114
# min         5.900000
# 25%         6.600000
# 50%         8.000000
# 75%        10.400000
# max        13.500000
# Name: diabetes_prevalence, dtype: float64
# ---------------------------------
# infant_mortality_rate
# count    5946.00000
# mean       10.35000
# std         2.23756
# min         6.20000
# 25%         8.80000
# 50%        11.05000
# 75%        12.20000
# max        12.80000
# Name: infant_mortality_rate, dtype: float64
# ---------------------------------
# nurses_per_1000
# count    5946.000000
# mean        5.368367
# std         4.605664
# min         1.330900
# 25%         2.396100
# 50%         2.519700
# 75%        10.119000
# max        13.324800
# Name: nurses_per_1000, dtype: float64
# ---------------------------------
# physicians_per_1000
# count    5946.000000
# mean        2.436317
# std         0.802012
# min         1.304800
# 25%         2.164300
# 50%         2.283750
# 75%         2.591200
# max         3.990100
# Name: physicians_per_1000, dtype: float64
# ---------------------------------
# average_temperature_celsius
# count    5904.000000
# mean       21.006267
# std         5.919635
# min         3.432099
# 25%        17.165124
# 50%        21.954586
# 75%        25.241667
# max        39.138889
# Name: average_temperature_celsius, dtype: float64
# ---------------------------------
# minimum_temperature_celsius
# count    5905.000000
# mean       14.853639
# std         6.811126
# min        -6.152778
# 25%         9.650000
# 50%        15.916667
# 75%        20.222222
# max        33.000000
# Name: minimum_temperature_celsius, dtype: float64
# ---------------------------------
# maximum_temperature_celsius
# count    5905.000000
# mean       27.077382
# std         5.271198
# min         6.950617
# 25%        24.083333
# 50%        27.416667
# 75%        30.697531
# max        41.944444
# Name: maximum_temperature_celsius, dtype: float64
# ---------------------------------
# rainfall_mm
# count    5809.000000
# mean        1.366397
# std         4.132483
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.338667
# max        60.388500
# Name: rainfall_mm, dtype: float64
# ---------------------------------
# relative_humidity
# count    5904.000000
# mean       61.719640
# std        15.395268
# min        10.296407
# 25%        51.860841
# 50%        64.303182
# 75%        73.318747
# max        96.064662
# Name: relative_humidity, dtype: float64
# ---------------------------------
# population_largest_city
# count    5.946000e+03
# mean     1.443888e+07
# std      5.709794e+06
# min      6.723516e+06
# 25%      1.055471e+07
# 50%      1.291832e+07
# 75%      2.167191e+07
# max      2.184651e+07
# Name: population_largest_city, dtype: float64
# ---------------------------------
# area_rural_sq_km
# count    5.946000e+03
# mean     2.636580e+06
# std      2.584612e+06
# min      7.094180e+05
# 25%      1.090598e+06
# 50%      1.543881e+06
# 75%      2.690269e+06
# max      8.241430e+06
# Name: area_rural_sq_km, dtype: float64
# ---------------------------------
# area_urban_sq_km
# count      5946.000000
# mean      59502.500000
# std       45123.088018
# min       12027.000000
# 25%       16425.000000
# 50%       45582.000000
# 75%      102418.000000
# max      134981.000000
# Name: area_urban_sq_km, dtype: float64
# ---------------------------------
# life_expectancy
# count    5946.000000
# mean       76.808500
# std         1.597315
# min        74.992000
# 25%        75.672000
# 50%        76.518000
# 75%        77.109000
# max        80.042000
# Name: life_expectancy, dtype: float64
# ---------------------------------
# adult_male_mortality_rate
# count    5946.000000
# mean      154.274667
# std        26.998811
# min       107.669000
# 25%       146.370000
# 50%       149.351000
# 75%       184.379000
# max       188.528000
# Name: adult_male_mortality_rate, dtype: float64
# ---------------------------------
# adult_female_mortality_rate
# count    5946.00000
# mean       81.42800
# std        11.80004
# min        59.03500
# 25%        77.99900
# 50%        82.14900
# 75%        91.42100
# max        95.81500
# Name: adult_female_mortality_rate, dtype: float64
# ---------------------------------
# pollution_mortality_rate
# count    5946.000000
# mean       36.566667
# std        13.026925
# min        25.300000
# 25%        26.600000
# 50%        33.300000
# 75%        37.000000
# max        63.900000
# Name: pollution_mortality_rate, dtype: float64
# ---------------------------------
# comorbidity_mortality_rate
# count    5946.000000
# mean       14.816667
# std         1.665890
# min        12.400000
# 25%        12.600000
# 50%        15.750000
# 75%        15.800000
# max        16.600000
# Name: comorbidity_mortality_rate, dtype: float64
# ---------------------------------
# new_recovered
# count      2601.000000
# mean      15068.126874
# std       27210.252811
# min      -31119.000000
# 25%           0.000000
# 50%        2323.000000
# 75%       19557.000000
# max      282957.000000
# Name: new_recovered, dtype: float64
# ---------------------------------
# cumulative_recovered
# count    1.768000e+03
# mean     8.739772e+06
# std      1.038330e+07
# min      0.000000e+00
# 25%      4.689378e+05
# 50%      4.491062e+06
# 75%      1.669978e+07
# max      3.370623e+07
# Name: cumulative_recovered, dtype: float64
# ---------------------------------

# %%
i=0
while i<len(data_latinoamerica_paises.columns):
    print(data_latinoamerica_paises.columns[i])
    print(data_latinoamerica_paises[data_latinoamerica_paises.columns[i]].describe())
    print('-------------------------')
    i+=1
# Out:
# location_key
# count     5946
# unique       6
# top         AR
# freq       991
# Name: location_key, dtype: object
# -------------------------
# date
# count           5946
# unique           991
# top       2022-09-17
# freq               6
# Name: date, dtype: object
# -------------------------
# country_code
# count     5946
# unique       6
# top         AR
# freq       991
# Name: country_code, dtype: object
# -------------------------
# country_name
# count          5946
# unique            6
# top       Argentina
# freq            991
# Name: country_name, dtype: object
# -------------------------
# new_confirmed
# count      5925.000000
# mean      11156.570802
# std       20629.839506
# min        -573.000000
# 25%        1125.000000
# 50%        4017.000000
# 75%       11013.000000
# max      298408.000000
# Name: new_confirmed, dtype: float64
# -------------------------
# new_deceased
# count     5925.000000
# mean       267.599662
# std        443.214995
# min          0.000000
# 25%         19.000000
# 50%        108.000000
# 75%        354.000000
# max      11447.000000
# Name: new_deceased, dtype: float64
# -------------------------
# cumulative_confirmed
# count    5.925000e+03
# mean     4.537433e+06
# std      7.030426e+06
# min      0.000000e+00
# 25%      5.901740e+05
# 50%      2.123737e+06
# 75%      4.953702e+06
# max      3.456883e+07
# Name: cumulative_confirmed, dtype: float64
# -------------------------
# cumulative_deceased
# count      5925.000000
# mean     133922.916624
# std      166648.107888
# min           0.000000
# 25%       19820.000000
# 50%       83596.000000
# 75%      176696.000000
# max      685203.000000
# Name: cumulative_deceased, dtype: float64
# -------------------------
# cumulative_vaccine_doses_administered
# count    3.173000e+03
# mean     7.722195e+07
# std      9.582103e+07
# min      1.800000e+01
# 25%      1.526598e+07
# 50%      4.203961e+07
# 75%      8.245385e+07
# max      3.478685e+08
# Name: cumulative_vaccine_doses_administered, dtype: float64
# -------------------------
# population
# count    5.946000e+03
# mean     7.772147e+07
# std      6.713444e+07
# min      1.757400e+07
# 25%      2.938188e+07
# 50%      4.791080e+07
# 75%      1.109920e+08
# max      2.125594e+08
# Name: population, dtype: float64
# -------------------------
# population_male
# count    5.946000e+03
# mean     3.787035e+07
# std      3.318329e+07
# min      8.972014e+06
# 25%      1.445076e+07
# 50%      2.225416e+07
# 75%      5.485523e+07
# max      1.044358e+08
# Name: population_male, dtype: float64
# -------------------------
# population_female
# count    5.946000e+03
# mean     3.927162e+07
# std      3.448236e+07
# min      8.601989e+06
# 25%      1.493113e+07
# 50%      2.324582e+07
# 75%      5.748131e+07
# max      1.081236e+08
# Name: population_female, dtype: float64
# -------------------------
# population_rural
# count    5.946000e+03
# mean     1.255498e+07
# std      1.008024e+07
# min      2.341903e+06
# 25%      3.599141e+06
# 50%      8.316128e+06
# 75%      2.494867e+07
# max      2.780789e+07
# Name: population_rural, dtype: float64
# -------------------------
# population_urban
# count    5.946000e+03
# mean     6.833931e+07
# std      5.829241e+07
# min      1.661014e+07
# 25%      2.539034e+07
# 50%      4.108344e+07
# 75%      1.026269e+08
# max      1.832416e+08
# Name: population_urban, dtype: float64
# -------------------------
# population_density
# count    5946.000000
# mean       34.266833
# std        16.838641
# min        16.515000
# 25%        25.431000
# 50%        25.734500
# 75%        45.861000
# max        66.325000
# Name: population_density, dtype: float64
# -------------------------
# human_development_index
# count    5946.000000
# mean        0.777333
# std         0.036352
# min         0.747000
# 25%         0.750000
# 50%         0.755000
# 75%         0.825000
# max         0.832000
# Name: human_development_index, dtype: float64
# -------------------------
# population_age_00_09
# count    5.946000e+03
# mean     1.205908e+07
# std      9.755221e+06
# min      2.428079e+06
# 25%      5.140624e+06
# 50%      7.066513e+06
# 75%      2.157586e+07
# max      2.907691e+07
# Name: population_age_00_09, dtype: float64
# -------------------------
# population_age_10_19
# count    5.946000e+03
# mean     1.263694e+07
# std      1.034880e+07
# min      2.493879e+06
# 25%      5.035905e+06
# 50%      7.582694e+06
# 75%      2.196605e+07
# max      3.116045e+07
# Name: population_age_10_19, dtype: float64
# -------------------------
# population_age_20_29
# count    5.946000e+03
# mean     1.265890e+07
# std      1.082648e+07
# min      2.995538e+06
# 25%      4.895056e+06
# 50%      7.638860e+06
# 75%      1.868045e+07
# max      3.410464e+07
# Name: population_age_20_29, dtype: float64
# -------------------------
# population_age_30_39
# count    5.946000e+03
# mean     1.202553e+07
# std      1.098747e+07
# min      2.945404e+06
# 25%      4.379777e+06
# 50%      6.793724e+06
# 75%      1.676378e+07
# max      3.447676e+07
# Name: population_age_30_39, dtype: float64
# -------------------------
# population_age_40_49
# count    5.946000e+03
# mean     9.932776e+06
# std      9.358615e+06
# min      2.578404e+06
# 25%      3.660378e+06
# 50%      5.478956e+06
# 75%      1.293796e+07
# max      2.946201e+07
# Name: population_age_40_49, dtype: float64
# -------------------------
# population_age_50_59
# count    5.946000e+03
# mean     7.993603e+06
# std      7.665975e+06
# min      2.352271e+06
# 25%      2.772568e+06
# 50%      4.727962e+06
# 75%      8.959656e+06
# max      2.442120e+07
# Name: population_age_50_59, dtype: float64
# -------------------------
# population_age_60_69
# count    5.946000e+03
# mean     5.442399e+06
# std      5.270592e+06
# min      1.791787e+06
# 25%      1.846407e+06
# 50%      3.342804e+06
# 75%      5.433731e+06
# max      1.689686e+07
# Name: population_age_60_69, dtype: float64
# -------------------------
# population_age_70_79
# count    5.946000e+03
# mean     2.964913e+06
# std      2.702859e+06
# min      9.931260e+05
# 25%      1.078066e+06
# 50%      1.898659e+06
# 75%      3.119417e+06
# max      8.801551e+06
# Name: population_age_70_79, dtype: float64
# -------------------------
# population_age_80_and_older
# count    5.946000e+03
# mean     1.451953e+06
# std      1.252107e+06
# min      5.377210e+05
# 25%      5.731030e+05
# 50%      9.698185e+05
# 75%      1.502231e+06
# max      4.159027e+06
# Name: population_age_80_and_older, dtype: float64
# -------------------------
# gdp_usd
# count    5.946000e+03
# mean     7.301129e+11
# std      6.066557e+11
# min      2.268481e+11
# 25%      2.823182e+11
# 50%      3.867331e+11
# 75%      1.258287e+12
# max      1.839758e+12
# Name: gdp_usd, dtype: float64
# -------------------------
# gdp_per_capita_usd
# count     5946.000000
# mean      9481.833333
# std       2765.911621
# min       6432.000000
# 25%       6977.000000
# 50%       9290.000000
# 75%      10006.000000
# max      14896.000000
# Name: gdp_per_capita_usd, dtype: float64
# -------------------------
# latitude
# count    5946.000000
# mean      -10.566667
# std        20.020147
# min       -34.000000
# 25%       -33.000000
# 50%       -11.700000
# 75%         4.000000
# max        23.000000
# Name: latitude, dtype: float64
# -------------------------
# longitude
# count    5946.000000
# mean      -73.208333
# std        14.916583
# min      -102.000000
# 25%       -76.000000
# 50%       -72.125000
# 75%       -64.000000
# max       -53.000000
# Name: longitude, dtype: float64
# -------------------------
# area_sq_km
# count    5.946000e+03
# mean     2.740702e+06
# std      2.663775e+06
# min      7.567000e+05
# 25%      1.141748e+06
# 50%      1.624798e+06
# 75%      2.780400e+06
# max      8.515770e+06
# Name: area_sq_km, dtype: float64
# -------------------------
# smoking_prevalence
# count    5946.000000
# mean       16.883333
# std        10.701744
# min         4.800000
# 25%         9.000000
# 50%        13.950000
# 75%        21.800000
# max        37.800000
# Name: smoking_prevalence, dtype: float64
# -------------------------
# diabetes_prevalence
# count    5946.000000
# mean        8.733333
# std         2.578114
# min         5.900000
# 25%         6.600000
# 50%         8.000000
# 75%        10.400000
# max        13.500000
# Name: diabetes_prevalence, dtype: float64
# -------------------------
# infant_mortality_rate
# count    5946.00000
# mean       10.35000
# std         2.23756
# min         6.20000
# 25%         8.80000
# 50%        11.05000
# 75%        12.20000
# max        12.80000
# Name: infant_mortality_rate, dtype: float64
# -------------------------
# nurses_per_1000
# count    5946.000000
# mean        5.368367
# std         4.605664
# min         1.330900
# 25%         2.396100
# 50%         2.519700
# 75%        10.119000
# max        13.324800
# Name: nurses_per_1000, dtype: float64
# -------------------------
# physicians_per_1000
# count    5946.000000
# mean        2.436317
# std         0.802012
# min         1.304800
# 25%         2.164300
# 50%         2.283750
# 75%         2.591200
# max         3.990100
# Name: physicians_per_1000, dtype: float64
# -------------------------
# average_temperature_celsius
# count    5904.000000
# mean       21.006267
# std         5.919635
# min         3.432099
# 25%        17.165124
# 50%        21.954586
# 75%        25.241667
# max        39.138889
# Name: average_temperature_celsius, dtype: float64
# -------------------------
# minimum_temperature_celsius
# count    5905.000000
# mean       14.853639
# std         6.811126
# min        -6.152778
# 25%         9.650000
# 50%        15.916667
# 75%        20.222222
# max        33.000000
# Name: minimum_temperature_celsius, dtype: float64
# -------------------------
# maximum_temperature_celsius
# count    5905.000000
# mean       27.077382
# std         5.271198
# min         6.950617
# 25%        24.083333
# 50%        27.416667
# 75%        30.697531
# max        41.944444
# Name: maximum_temperature_celsius, dtype: float64
# -------------------------
# rainfall_mm
# count    5809.000000
# mean        1.366397
# std         4.132483
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.338667
# max        60.388500
# Name: rainfall_mm, dtype: float64
# -------------------------
# relative_humidity
# count    5904.000000
# mean       61.719640
# std        15.395268
# min        10.296407
# 25%        51.860841
# 50%        64.303182
# 75%        73.318747
# max        96.064662
# Name: relative_humidity, dtype: float64
# -------------------------
# population_largest_city
# count    5.946000e+03
# mean     1.443888e+07
# std      5.709794e+06
# min      6.723516e+06
# 25%      1.055471e+07
# 50%      1.291832e+07
# 75%      2.167191e+07
# max      2.184651e+07
# Name: population_largest_city, dtype: float64
# -------------------------
# area_rural_sq_km
# count    5.946000e+03
# mean     2.636580e+06
# std      2.584612e+06
# min      7.094180e+05
# 25%      1.090598e+06
# 50%      1.543881e+06
# 75%      2.690269e+06
# max      8.241430e+06
# Name: area_rural_sq_km, dtype: float64
# -------------------------
# area_urban_sq_km
# count      5946.000000
# mean      59502.500000
# std       45123.088018
# min       12027.000000
# 25%       16425.000000
# 50%       45582.000000
# 75%      102418.000000
# max      134981.000000
# Name: area_urban_sq_km, dtype: float64
# -------------------------
# life_expectancy
# count    5946.000000
# mean       76.808500
# std         1.597315
# min        74.992000
# 25%        75.672000
# 50%        76.518000
# 75%        77.109000
# max        80.042000
# Name: life_expectancy, dtype: float64
# -------------------------
# adult_male_mortality_rate
# count    5946.000000
# mean      154.274667
# std        26.998811
# min       107.669000
# 25%       146.370000
# 50%       149.351000
# 75%       184.379000
# max       188.528000
# Name: adult_male_mortality_rate, dtype: float64
# -------------------------
# adult_female_mortality_rate
# count    5946.00000
# mean       81.42800
# std        11.80004
# min        59.03500
# 25%        77.99900
# 50%        82.14900
# 75%        91.42100
# max        95.81500
# Name: adult_female_mortality_rate, dtype: float64
# -------------------------
# pollution_mortality_rate
# count    5946.000000
# mean       36.566667
# std        13.026925
# min        25.300000
# 25%        26.600000
# 50%        33.300000
# 75%        37.000000
# max        63.900000
# Name: pollution_mortality_rate, dtype: float64
# -------------------------
# comorbidity_mortality_rate
# count    5946.000000
# mean       14.816667
# std         1.665890
# min        12.400000
# 25%        12.600000
# 50%        15.750000
# 75%        15.800000
# max        16.600000
# Name: comorbidity_mortality_rate, dtype: float64
# -------------------------
# new_recovered
# count      2601.000000
# mean      15068.126874
# std       27210.252811
# min      -31119.000000
# 25%           0.000000
# 50%        2323.000000
# 75%       19557.000000
# max      282957.000000
# Name: new_recovered, dtype: float64
# -------------------------
# cumulative_recovered
# count    1.768000e+03
# mean     8.739772e+06
# std      1.038330e+07
# min      0.000000e+00
# 25%      4.689378e+05
# 50%      4.491062e+06
# 75%      1.669978e+07
# max      3.370623e+07
# Name: cumulative_recovered, dtype: float64
# -------------------------

# %%
def describir_datos(data):
    for i in data.columns:
        if data[i].dtype == 'float64' or data[i].dtype == 'int64':
            print(i)
            print('Mediana:', data[i].median())
            print('Varianza:', data[i].var())
            print('Rango:', data[i].max() - data[i].min())
            print('Moda:', data[i].mode())
            print('-----------------------------')

describir_datos(data_latinoamerica_paises)
# Out:
# new_confirmed
# Mediana: 4017.0
# Varianza: 425590278.046514
# Rango: 298981.0
# Moda: 0    0.0
# Name: new_confirmed, dtype: float64
# -----------------------------
# new_deceased
# Mediana: 108.0
# Varianza: 196439.53146511223
# Rango: 11447.0
# Moda: 0    0.0
# Name: new_deceased, dtype: float64
# -----------------------------
# cumulative_confirmed
# Mediana: 2123737.0
# Varianza: 49426883938627.11
# Rango: 34568833.0
# Moda: 0    0.0
# Name: cumulative_confirmed, dtype: float64
# -----------------------------
# cumulative_deceased
# Mediana: 83596.0
# Varianza: 27771591862.60344
# Rango: 685203.0
# Moda: 0    0.0
# Name: cumulative_deceased, dtype: float64
# -----------------------------
# cumulative_vaccine_doses_administered
# Mediana: 42039612.0
# Varianza: 9181669571909644.0
# Rango: 347868463.0
# Moda: 0    209673612.0
# Name: cumulative_vaccine_doses_administered, dtype: float64
# -----------------------------
# population
# Mediana: 47910798.0
# Varianza: 4507032513124198.0
# Rango: 194985406.0
# Moda: 0     17574003.0
# 1     29381884.0
# 2     44938712.0
# 3     50882884.0
# 4    110991953.0
# 5    212559409.0
# Name: population, dtype: float64
# -----------------------------
# population_male
# Mediana: 22254165.0
# Varianza: 1101130994899747.8
# Rango: 95463769.0
# Moda: 0      8972014.0
# 1     14450757.0
# 2     19523766.0
# 3     24984564.0
# 4     54855231.0
# 5    104435783.0
# Name: population_male, dtype: float64
# -----------------------------
# population_female
# Mediana: 23245825.0
# Varianza: 1189033466364864.8
# Rango: 99521637.0
# Moda: 0      8601989.0
# 1     14931127.0
# 2     20593330.0
# 3     25898320.0
# 4     57481307.0
# 5    108123626.0
# Name: population_female, dtype: float64
# -----------------------------
# population_rural
# Mediana: 8316127.5
# Varianza: 101611309832907.27
# Rango: 25465983.0
# Moda: 0     2341903.0
# 1     3599141.0
# 2     7120114.0
# 3     9512141.0
# 4    24948670.0
# 5    27807886.0
# Name: population_rural, dtype: float64
# -----------------------------
# population_urban
# Mediana: 41083436.5
# Varianza: 3398004782770738.0
# Rango: 166631506.0
# Moda: 0     16610135.0
# 1     25390339.0
# 2     40827302.0
# 3     41339571.0
# 4    102626859.0
# 5    183241641.0
# Name: population_urban, dtype: float64
# -----------------------------
# population_density
# Mediana: 25.7345
# Varianza: 283.53983795085503
# Rango: 49.81
# Moda: 0    16.515
# 1    25.431
# 2    25.710
# 3    25.759
# 4    45.861
# 5    66.325
# Name: population_density, dtype: float64
# -----------------------------
# human_development_index
# Mediana: 0.755
# Varianza: 0.001321444463134285
# Rango: 0.08499999999999996
# Moda: 0    0.747
# 1    0.750
# 2    0.754
# 3    0.756
# 4    0.825
# 5    0.832
# Name: human_development_index, dtype: float64
# -----------------------------
# population_age_00_09
# Mediana: 7066513.0
# Varianza: 95164337190578.56
# Rango: 26648831.0
# Moda: 0     2428079.0
# 1     5140624.0
# 2     6718871.0
# 3     7414155.0
# 4    21575859.0
# 5    29076910.0
# Name: population_age_00_09, dtype: float64
# -----------------------------
# population_age_10_19
# Mediana: 7582694.5
# Varianza: 107097660359358.98
# Rango: 28666567.0
# Moda: 0     2493879.0
# 1     5035905.0
# 2     7045513.0
# 3     8119876.0
# 4    21966049.0
# 5    31160446.0
# Name: population_age_10_19, dtype: float64
# -----------------------------
# population_age_20_29
# Mediana: 7638859.5
# Varianza: 117212694016488.4
# Rango: 31109105.0
# Moda: 0     2995538.0
# 1     4895056.0
# 2     6430658.0
# 3     8847061.0
# 4    18680448.0
# 5    34104643.0
# Name: population_age_20_29, dtype: float64
# -----------------------------
# population_age_30_39
# Mediana: 6793723.5
# Varianza: 120724562804730.34
# Rango: 31531358.0
# Moda: 0     2945404.0
# 1     4379777.0
# 2     5777148.0
# 3     7810299.0
# 4    16763785.0
# 5    34476762.0
# Name: population_age_30_39, dtype: float64
# -----------------------------
# population_age_40_49
# Mediana: 5478956.0
# Varianza: 87583668443362.47
# Rango: 26883602.0
# Moda: 0     2578404.0
# 1     3660378.0
# 2     4507125.0
# 3     6450787.0
# 4    12937956.0
# 5    29462006.0
# Name: population_age_40_49, dtype: float64
# -----------------------------
# population_age_50_59
# Mediana: 4727961.5
# Varianza: 58767167096959.85
# Rango: 22068931.0
# Moda: 0     2352271.0
# 1     2772568.0
# 2     3911943.0
# 3     5543980.0
# 4     8959656.0
# 5    24421202.0
# Name: population_age_50_59, dtype: float64
# -----------------------------
# population_age_60_69
# Mediana: 3342804.5
# Varianza: 27779144325325.87
# Rango: 15105075.0
# Moda: 0     1791787.0
# 1     1846407.0
# 2     2914251.0
# 3     3771358.0
# 4     5433731.0
# 5    16896862.0
# Name: population_age_60_69, dtype: float64
# -----------------------------
# population_age_70_79
# Mediana: 1898659.0
# Varianza: 7305445374862.725
# Rango: 7808425.0
# Moda: 0     993126.0
# 1    1078066.0
# 2    1817557.0
# 3    1979761.0
# 4    3119417.0
# 5    8801551.0
# Name: population_age_70_79, dtype: float64
# -----------------------------
# population_age_80_and_older
# Mediana: 969818.5
# Varianza: 1567772791269.6843
# Rango: 3621306.0
# Moda: 0     537721.0
# 1     573103.0
# 2     945607.0
# 3     994030.0
# 4    1502231.0
# 5    4159027.0
# Name: population_age_80_and_older, dtype: float64
# -----------------------------
# gdp_usd
# Mediana: 386733127531.0
# Varianza: 3.6803111955146455e+23
# Rango: 1612909989946.0
# Moda: 0    2.268481e+11
# 1    2.823182e+11
# 2    3.238028e+11
# 3    4.496634e+11
# 4    1.258287e+12
# 5    1.839758e+12
# Name: gdp_usd, dtype: float64
# -----------------------------
# gdp_per_capita_usd
# Mediana: 9290.0
# Varianza: 7650267.096355483
# Rango: 8464.0
# Moda: 0     6432.0
# 1     6977.0
# 2     8717.0
# 3     9863.0
# 4    10006.0
# 5    14896.0
# Name: gdp_per_capita_usd, dtype: float64
# -----------------------------
# latitude
# Mediana: -11.7
# Varianza: 400.80629660779357
# Rango: 57.0
# Moda: 0   -34.0
# 1   -33.0
# 2   -14.0
# 3    -9.4
# 4     4.0
# 5    23.0
# Name: latitude, dtype: float64
# -----------------------------
# longitude
# Mediana: -72.125
# Varianza: 222.50443474908883
# Rango: 49.0
# Moda: 0   -102.00
# 1    -76.00
# 2    -73.25
# 3    -71.00
# 4    -64.00
# 5    -53.00
# Name: longitude, dtype: float64
# -----------------------------
# area_sq_km
# Mediana: 1624797.5
# Varianza: 7095695961066.111
# Rango: 7759070.0
# Moda: 0     756700.0
# 1    1141748.0
# 2    1285220.0
# 3    1964375.0
# 4    2780400.0
# 5    8515770.0
# Name: area_sq_km, dtype: float64
# -----------------------------
# smoking_prevalence
# Mediana: 13.95
# Varianza: 114.5273167928231
# Rango: 33.0
# Moda: 0     4.8
# 1     9.0
# 2    13.9
# 3    14.0
# 4    21.8
# 5    37.8
# Name: smoking_prevalence, dtype: float64
# -----------------------------
# diabetes_prevalence
# Mediana: 8.0
# Varianza: 6.646673395009814
# Rango: 7.6
# Moda: 0     5.9
# 1     6.6
# 2     7.4
# 3     8.6
# 4    10.4
# 5    13.5
# Name: diabetes_prevalence, dtype: float64
# -----------------------------
# infant_mortality_rate
# Mediana: 11.05
# Varianza: 5.00667535744323
# Rango: 6.6000000000000005
# Moda: 0     6.2
# 1     8.8
# 2    11.0
# 3    11.1
# 4    12.2
# 5    12.8
# Name: infant_mortality_rate, dtype: float64
# -----------------------------
# nurses_per_1000
# Mediana: 2.5197000000000003
# Varianza: 21.21213850581217
# Rango: 11.9939
# Moda: 0     1.3309
# 1     2.3961
# 2     2.4398
# 3     2.5996
# 4    10.1190
# 5    13.3248
# Name: nurses_per_1000, dtype: float64
# -----------------------------
# physicians_per_1000
# Mediana: 2.28375
# Varianza: 0.6432231621797029
# Rango: 2.6853
# Moda: 0    1.3048
# 1    2.1643
# 2    2.1848
# 3    2.3827
# 4    2.5912
# 5    3.9901
# Name: physicians_per_1000, dtype: float64
# -----------------------------
# average_temperature_celsius
# Mediana: 21.9545855
# Varianza: 35.042079951721064
# Rango: 35.70679
# Moda: 0    28.0
# Name: average_temperature_celsius, dtype: float64
# -----------------------------
# minimum_temperature_celsius
# Mediana: 15.916667
# Varianza: 46.39143350019171
# Rango: 39.152778
# Moda: 0    23.0
# Name: minimum_temperature_celsius, dtype: float64
# -----------------------------
# maximum_temperature_celsius
# Mediana: 27.416667
# Varianza: 27.785525815939458
# Rango: 34.993826999999996
# Moda: 0    20.0
# Name: maximum_temperature_celsius, dtype: float64
# -----------------------------
# rainfall_mm
# Mediana: 0.0
# Varianza: 17.07741540007342
# Rango: 60.3885
# Moda: 0    0.0
# Name: rainfall_mm, dtype: float64
# -----------------------------
# relative_humidity
# Mediana: 64.30318249999999
# Varianza: 237.01428781511981
# Rango: 85.768255
# Moda: 0    32.277552
# 1    74.302363
# 2    76.725537
# Name: relative_humidity, dtype: float64
# -----------------------------
# population_largest_city
# Mediana: 12918324.5
# Varianza: 32601751964255.06
# Rango: 15122991.0
# Moda: 0     6723516.0
# 1    10554712.0
# 2    10779376.0
# 3    15057273.0
# 4    21671908.0
# 5    21846507.0
# Name: population_largest_city, dtype: float64
# -----------------------------
# area_rural_sq_km
# Mediana: 1543881.0
# Varianza: 6680220608520.579
# Rango: 7532012.0
# Moda: 0     709418.0
# 1    1090598.0
# 2    1256339.0
# 3    1831423.0
# 4    2690269.0
# 5    8241430.0
# Name: area_rural_sq_km, dtype: float64
# -----------------------------
# area_urban_sq_km
# Mediana: 45582.0
# Varianza: 2036093072.3052144
# Rango: 122954.0
# Moda: 0     12027.0
# 1     16425.0
# 2     36132.0
# 3     55032.0
# 4    102418.0
# 5    134981.0
# Name: area_urban_sq_km, dtype: float64
# -----------------------------
# life_expectancy
# Mediana: 76.518
# Varianza: 2.5514150143818326
# Rango: 5.049999999999997
# Moda: 0    74.992
# 1    75.672
# 2    76.516
# 3    76.520
# 4    77.109
# 5    80.042
# Name: life_expectancy, dtype: float64
# -----------------------------
# adult_male_mortality_rate
# Mediana: 149.351
# Varianza: 728.9357738515278
# Rango: 80.859
# Moda: 0    107.669
# 1    146.370
# 2    147.086
# 3    151.616
# 4    184.379
# 5    188.528
# Name: adult_male_mortality_rate, dtype: float64
# -----------------------------
# adult_female_mortality_rate
# Mediana: 82.149
# Varianza: 139.24093458065607
# Rango: 36.78
# Moda: 0    59.035
# 1    77.999
# 2    79.483
# 3    84.815
# 4    91.421
# 5    95.815
# Name: adult_female_mortality_rate, dtype: float64
# -----------------------------
# pollution_mortality_rate
# Mediana: 33.3
# Varianza: 169.70076254555647
# Rango: 38.599999999999994
# Moda: 0    25.3
# 1    26.6
# 2    29.9
# 3    36.7
# 4    37.0
# 5    63.9
# Name: pollution_mortality_rate, dtype: float64
# -----------------------------
# comorbidity_mortality_rate
# Mediana: 15.75
# Varianza: 2.775188954303337
# Rango: 4.200000000000001
# Moda: 0    15.8
# Name: comorbidity_mortality_rate, dtype: float64
# -----------------------------
# new_recovered
# Mediana: 2323.0
# Varianza: 740397858.0631276
# Rango: 314076.0
# Moda: 0    0.0
# Name: new_recovered, dtype: float64
# -----------------------------
# cumulative_recovered
# Mediana: 4491062.5
# Varianza: 107813006945430.31
# Rango: 33706231.0
# Moda: 0    0.0
# Name: cumulative_recovered, dtype: float64
# -----------------------------

# %% [markdown]
# # **Segundo Avance**

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
# Diagramas
for i in data_latinoamerica_paises.columns:
    if i not in ['location_key', 'date', 'country_code', 'country_name', 'latitude', 'longitude', 
                 'cumulative_confirmed', 'cumulative_deceased', 'cumulative_recovered', 
                 'cumulative_vaccine_doses_administered', 'new_recovered']:
        fig, ax = plt.subplots(figsize=(5, 3))
        sns.barplot(x='country_name', y=i, data=data_latinoamerica_paises, ax=ax, hue='country_name')
        plt.title(f'{i} por país en latinoamérica')
        plt.show()

# %%
lista_columnas_6 = ["new_confirmed", "new_deceased", "average_temperature_celsius", 
                    "minimum_temperature_celsius", "maximum_temperature_celsius", "relative_humidity"]

# Histogramas
for i in data_latinoamerica_paises[lista_columnas_6]:
        fig, ax = plt.subplots(figsize=(8, 6))
        sns.histplot(data_latinoamerica_paises[i], kde=True)
        plt.title(i)
        plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 6))
sns.scatterplot(x='average_temperature_celsius', y='new_confirmed', 
                data=data_latinoamerica_paises, hue='country_name')
plt.title('average_temperature_celsius vs new_confirmed')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 6))
sns.scatterplot(y='average_temperature_celsius', x='new_deceased', data=data_latinoamerica_paises, hue='country_name')
plt.title('average_temperature_celsius vs new_deceased')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
# Gráfica de valores medios de todos los países cumulative_vaccine_doses_administered
fig, ax = plt.subplots(figsize=(10, 6))

# Filtra los datos para que empiecen en enero de 2021
data_2021 = data_latinoamerica_paises.loc['2021-01-01':]

data_2021.resample('M').mean(numeric_only=True)['cumulative_vaccine_doses_administered'].plot(ax=ax)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.title('cumulative_vaccine_doses_administered por mes de todos los países')
plt.show()
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_9900\705773117.py:7: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   data_2021.resample('M').mean(numeric_only=True)['cumulative_vaccine_doses_administered'].plot(ax=ax)

# %%
# Revisar si 'date' columna existe y convertirla a datetime
if 'date' in data_latinoamerica_paises.columns:
    data_latinoamerica_paises['date'] = pd.to_datetime(data_latinoamerica_paises['date'], errors='coerce')
    data_latinoamerica_paises.set_index('date', inplace=True)
else:
    print("No se encontró la columna 'date'. Verifica que esté presente en el DataFrame.")

# Filtrar los datos para incluir solo fechas desde enero de 2021 en adelante
data_filtered = data_latinoamerica_paises[data_latinoamerica_paises.index >= '2021-01-01']

# Verificar que el índice sea de tipo datetime
print("Tipo de índice:", type(data_filtered.index))

# Realizar el resampling y la gráfica
fig, ax = plt.subplots(figsize=(10, 6))
for pais in paises_seleccionados:
    data_pais = data_filtered[data_filtered['country_name'] == pais]
    if not data_pais.empty:
        data_pais.resample('M').mean(numeric_only=True)['cumulative_vaccine_doses_administered'].plot(ax=ax)
    else:
        print(f"No hay datos para el país: {pais}")

plt.title('Evolución de dosis administradas por mes de cada país desde 2021')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.legend(paises_seleccionados)
plt.show()
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_14824\3905463430.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_latinoamerica_paises['date'] = pd.to_datetime(data_latinoamerica_paises['date'], errors='coerce')
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_14824\3905463430.py:19: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   data_pais.resample('M').mean(numeric_only=True)['cumulative_vaccine_doses_administered'].plot(ax=ax)
# Tipo de índice: <class 'pandas.core.indexes.datetimes.DatetimeIndex'>
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_14824\3905463430.py:19: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   data_pais.resample('M').mean(numeric_only=True)['cumulative_vaccine_doses_administered'].plot(ax=ax)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_14824\3905463430.py:19: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   data_pais.resample('M').mean(numeric_only=True)['cumulative_vaccine_doses_administered'].plot(ax=ax)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_14824\3905463430.py:19: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   data_pais.resample('M').mean(numeric_only=True)['cumulative_vaccine_doses_administered'].plot(ax=ax)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_14824\3905463430.py:19: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   data_pais.resample('M').mean(numeric_only=True)['cumulative_vaccine_doses_administered'].plot(ax=ax)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_14824\3905463430.py:19: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   data_pais.resample('M').mean(numeric_only=True)['cumulative_vaccine_doses_administered'].plot(ax=ax)

# %%
fig, ax = plt.subplots(figsize=(10, 6))
for pais in paises_seleccionados:
    data_filtrada = data_latinoamerica_paises[(data_latinoamerica_paises['country_name'] == pais) & (data_latinoamerica_paises.index >= '2021-01-01')]
    data_filtrada.resample('M').mean(numeric_only=True)['cumulative_deceased'].plot(ax=ax, label=pais)
plt.title('Muertes por mes de cada país desde 2021')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_14824\2186888646.py:4: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   data_filtrada.resample('M').mean(numeric_only=True)['cumulative_deceased'].plot(ax=ax, label=pais)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_14824\2186888646.py:4: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   data_filtrada.resample('M').mean(numeric_only=True)['cumulative_deceased'].plot(ax=ax, label=pais)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_14824\2186888646.py:4: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   data_filtrada.resample('M').mean(numeric_only=True)['cumulative_deceased'].plot(ax=ax, label=pais)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_14824\2186888646.py:4: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   data_filtrada.resample('M').mean(numeric_only=True)['cumulative_deceased'].plot(ax=ax, label=pais)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_14824\2186888646.py:4: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   data_filtrada.resample('M').mean(numeric_only=True)['cumulative_deceased'].plot(ax=ax, label=pais)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_14824\2186888646.py:4: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   data_filtrada.resample('M').mean(numeric_only=True)['cumulative_deceased'].plot(ax=ax, label=pais)

# %%
data_filtered = data_latinoamerica_paises[data_latinoamerica_paises.index >= '2021-01-01']

fig, ax = plt.subplots(figsize=(10, 6))
for pais in paises_seleccionados:
    data_filtered[data_filtered['country_name'] == pais].resample('M').mean(numeric_only=True)['cumulative_confirmed'].plot(ax=ax)

plt.title('Casos confirmados por mes de cada país')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.legend(paises_seleccionados)
plt.show()
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_14824\1956848528.py:5: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   data_filtered[data_filtered['country_name'] == pais].resample('M').mean(numeric_only=True)['cumulative_confirmed'].plot(ax=ax)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_14824\1956848528.py:5: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   data_filtered[data_filtered['country_name'] == pais].resample('M').mean(numeric_only=True)['cumulative_confirmed'].plot(ax=ax)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_14824\1956848528.py:5: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   data_filtered[data_filtered['country_name'] == pais].resample('M').mean(numeric_only=True)['cumulative_confirmed'].plot(ax=ax)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_14824\1956848528.py:5: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   data_filtered[data_filtered['country_name'] == pais].resample('M').mean(numeric_only=True)['cumulative_confirmed'].plot(ax=ax)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_14824\1956848528.py:5: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   data_filtered[data_filtered['country_name'] == pais].resample('M').mean(numeric_only=True)['cumulative_confirmed'].plot(ax=ax)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_14824\1956848528.py:5: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   data_filtered[data_filtered['country_name'] == pais].resample('M').mean(numeric_only=True)['cumulative_confirmed'].plot(ax=ax)

# %%
fig, ax = plt.subplots(figsize=(10, 6))

# Filtrar los datos desde el 2021
data_filtrada = data_latinoamerica_paises[data_latinoamerica_paises.index >= '2021-01-01']

for pais in paises_seleccionados:
    data_filtrada[data_filtrada['country_name'] == pais].resample('M').mean(numeric_only=True)['cumulative_recovered'].plot()

plt.title('Recuperaciones de casos por mes de cada país desde 2021')
plt.legend(paises_seleccionados, bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

#Esta grafica es incorrecta por exceso de nulos
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_14824\1409711687.py:7: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   data_filtrada[data_filtrada['country_name'] == pais].resample('M').mean(numeric_only=True)['cumulative_recovered'].plot()
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_14824\1409711687.py:7: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   data_filtrada[data_filtrada['country_name'] == pais].resample('M').mean(numeric_only=True)['cumulative_recovered'].plot()
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_14824\1409711687.py:7: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   data_filtrada[data_filtrada['country_name'] == pais].resample('M').mean(numeric_only=True)['cumulative_recovered'].plot()
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_14824\1409711687.py:7: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   data_filtrada[data_filtrada['country_name'] == pais].resample('M').mean(numeric_only=True)['cumulative_recovered'].plot()
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_14824\1409711687.py:7: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   data_filtrada[data_filtrada['country_name'] == pais].resample('M').mean(numeric_only=True)['cumulative_recovered'].plot()
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_14824\1409711687.py:7: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   data_filtrada[data_filtrada['country_name'] == pais].resample('M').mean(numeric_only=True)['cumulative_recovered'].plot()

# %%
fig, ax = plt.subplots(figsize=(10, 6))


data_filtrada = data_latinoamerica_paises[data_latinoamerica_paises.index >= '2021-01-01']

for pais in paises_seleccionados:
    data_filtrada[data_filtrada['country_name'] == pais].resample('M').mean(numeric_only=True)['new_confirmed'].plot(ax=ax)

plt.title('Comparación del Número de Casos Nuevos entre Países de América Latina (Desde 2021)')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.legend(paises_seleccionados)
plt.show()
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_14824\4199161290.py:7: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   data_filtrada[data_filtrada['country_name'] == pais].resample('M').mean(numeric_only=True)['new_confirmed'].plot(ax=ax)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_14824\4199161290.py:7: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   data_filtrada[data_filtrada['country_name'] == pais].resample('M').mean(numeric_only=True)['new_confirmed'].plot(ax=ax)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_14824\4199161290.py:7: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   data_filtrada[data_filtrada['country_name'] == pais].resample('M').mean(numeric_only=True)['new_confirmed'].plot(ax=ax)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_14824\4199161290.py:7: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   data_filtrada[data_filtrada['country_name'] == pais].resample('M').mean(numeric_only=True)['new_confirmed'].plot(ax=ax)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_14824\4199161290.py:7: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   data_filtrada[data_filtrada['country_name'] == pais].resample('M').mean(numeric_only=True)['new_confirmed'].plot(ax=ax)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_14824\4199161290.py:7: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   data_filtrada[data_filtrada['country_name'] == pais].resample('M').mean(numeric_only=True)['new_confirmed'].plot(ax=ax)

# %%
# Asegurarse de que no haya nombres de columna duplicados
data_latinoamerica_paises.columns = [f'{col}_{i}' if list(data_latinoamerica_paises.columns).count(col) > 1 else col for i, col in enumerate(data_latinoamerica_paises.columns)]

# Asegurarse de que no haya índices duplicados
data_latinoamerica_paises = data_latinoamerica_paises.reset_index(drop=True)

# Se crea un dataframe con las columnas mayores a 6 porque son las que tienen valores diferentes para cada país.
columnas_mayores_6 = []
for i in data_latinoamerica_paises.columns:
    if i not in ['location_key', 'date', 'country_code', 'latitude', 'longitude']:
        if data_latinoamerica_paises[i].nunique() > 6:
            columnas_mayores_6.append(i)

# agregar a columnas_mayores_6 la columna country_name para poder hacer analisis por país.
columnas_mayores_6.append('country_name')

# Se crea un dataframe con las columnas mayores a 6
data_latinoamerica_paises_mayores_6 = data_latinoamerica_paises[columnas_mayores_6]

# violinplot en todos los paises para variables numericas
for i in data_latinoamerica_paises_mayores_6.columns:
    if i not in ['location_key', 'date', 'country_code', 'latitude', 'longitude', 'country_name']:
        fig, ax = plt.subplots(figsize=(10, 6))
        sns.violinplot(x='country_name', y=i, data=data_latinoamerica_paises_mayores_6, hue='country_name')
        plt.title(f'{i} por país en latinoamerica')
        plt.show()

# %%
# Calculamos la distribución de la población por grupos de edad
age_columns = ['population_age_00_09', 'population_age_10_19', 'population_age_20_29', 'population_age_30_39', 'population_age_40_49', 'population_age_50_59', 'population_age_60_69', 'population_age_70_79']
age_distribution = data_latinoamerica_paises[age_columns].sum()

plt.figure(figsize=(10, 6))
age_distribution.plot(kind='bar', stacked=True)
plt.xlabel('Age Groups')
plt.ylabel('Population')
plt.title('Distribución de la población por grupos de edad')
plt.xticks(range(len(age_columns)), [col.split('_')[-2] + '-' + col.split('_')[-1] for col in age_columns], rotation=45)

plt.show()

# %%
correlation_matrix = data_latinoamerica_paises[['population_density', 'smoking_prevalence', 'diabetes_prevalence', 'cumulative_deceased', 'human_development_index']].corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', center=0)
plt.title('Matriz de correlación de indicadores demográficos y de salud')
plt.show()

# %% [markdown]
# # **Tercer Avance**

# %%
vaccination_data = data_latinoamerica_paises.groupby('country_name')['cumulative_vaccine_doses_administered'].max().sort_values(ascending=False)

plt.figure(figsize=(12, 8))
sns.barplot(x=vaccination_data.values, y=vaccination_data.index, hue=vaccination_data.index, palette='viridis')
plt.xlabel('Dosis de vacunas administradas')
plt.ylabel('País')
plt.title('Progreso de la vacunación por país')

plt.show()

# %%
data_latinoamerica_paises['urban_population_percentage'] = data_latinoamerica_paises['population_urban'] / data_latinoamerica_paises['population']
urban_cases = data_latinoamerica_paises.groupby('country_name').last().sort_values(by='urban_population_percentage')

plt.figure(figsize=(12, 8))
sns.barplot(x=urban_cases['urban_population_percentage'], y=urban_cases.index, palette='viridis')
plt.xlabel('Porcentaje de Población Urbana')
plt.title('Impacto de la Urbanización en la Propagación del COVID-19 en América Latina')
plt.show()
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_17356\2958422060.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=urban_cases['urban_population_percentage'], y=urban_cases.index, palette='viridis')

# %%
high_mortality_countries = data_latinoamerica_paises.groupby('country_name')['cumulative_deceased'].max().sort_values(ascending=False).head(5).index
age_groups = ['population_age_00_09', 'population_age_10_19', 'population_age_20_29', 'population_age_30_39', 'population_age_40_49', 'population_age_50_59', 'population_age_60_69', 'population_age_70_79', 'population_age_80_and_older']
age_distribution = data_latinoamerica_paises[data_latinoamerica_paises['country_name'].isin(high_mortality_countries)].groupby('country_name')[age_groups].mean()

age_distribution.plot(kind='bar', stacked=True, figsize=(12, 8))
plt.xlabel('País')
plt.ylabel('Distribución de la Población por Edad')
plt.title('Distribución de la Población por Edad en Países con Altas Tasas de Mortalidad por COVID-19')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', title='Grupo de Edad')
plt.show()

# %%
vaccination_strategy = data_latinoamerica_paises.groupby('country_name')['cumulative_vaccine_doses_administered'].max() / data_latinoamerica_paises.groupby('country_name')['population'].mean() * 100
vaccination_strategy.sort_values(ascending=False).plot(kind='bar', figsize=(12, 8), color='teal')
plt.xlabel('País')
plt.ylabel('Dosis Administradas por cada 100 Personas')
plt.title('Comparación de Estrategias de Vacunación en América Latina')
plt.show()

# %%
# Prevalencia de diabetes.
top_countries = data_latinoamerica_paises.groupby('country_name')['cumulative_deceased'].max().nlargest(5).index
bottom_countries = data_latinoamerica_paises.groupby('country_name')['cumulative_deceased'].max().nsmallest(5).index
conditions_data = data_latinoamerica_paises[data_latinoamerica_paises['country_name'].isin(top_countries.union(bottom_countries))]
plt.figure(figsize=(14, 8))
sns.barplot(data=conditions_data, x='country_name', y='diabetes_prevalence', hue='country_name')
plt.xlabel('País')
plt.ylabel('Prevalencia de Diabetes (%)')
plt.title('Prevalencia de Condiciones Preexistentes en Países con Altas y Bajas Tasas de Mortalidad por COVID-19')
plt.show()

# Prevalencia de fumar.
plt.figure(figsize=(14, 8))
sns.barplot(data=conditions_data, x='country_name', y='smoking_prevalence', hue='country_name')
plt.xlabel('País')
plt.ylabel('Prevalencia de Fumar (%)')
plt.title('Prevalencia de Fumar en Países con Altas y Bajas Tasas de Mortalidad por COVID-19')
plt.show()

# %%
data_latinoamerica_paises['case_fatality_rate'] = data_latinoamerica_paises['cumulative_deceased'] / data_latinoamerica_paises['cumulative_confirmed']
fatality_rates = data_latinoamerica_paises.groupby('country_name')['case_fatality_rate'].last().sort_values()

plt.figure(figsize=(12, 8))
fatality_rates.plot(kind='bar', color='maroon')
plt.xlabel('País')
plt.ylabel('Tasa de Letalidad')
plt.title('Comparación de la Tasa de Letalidad del COVID-19 Entre Países de América Latina')
plt.show()

# %%
data_latinoamerica_paises['mortality_rate'] = data_latinoamerica_paises['cumulative_deceased'] / data_latinoamerica_paises['cumulative_confirmed']

plt.figure(figsize=(14, 7))
sns.lineplot(data=data_latinoamerica_paises, x='date', y='mortality_rate', estimator='mean', ci=None)
plt.title('Temporal Analysis of COVID-19 Mortality in Latin America')
plt.xlabel('Date')
plt.ylabel('Mortality Rate')
plt.show()


#No funciona-- Preguntar a Mario

#Puede ser por exceso de nulos
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_17356\2855993723.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(data=data_latinoamerica_paises, x='date', y='mortality_rate', estimator='mean', ci=None)

# %%
# Evolución de los casos activos y recuperados en América Latina
data_latinoamerica_paises['active_cases'] = data_latinoamerica_paises['cumulative_confirmed'] - data_latinoamerica_paises['cumulative_deceased'] - data_latinoamerica_paises['cumulative_recovered']

# Revisar si 'date' columna existe y convertirla a datetime
if 'date' in data_latinoamerica_paises.columns:
    data_latinoamerica_paises['date'] = pd.to_datetime(data_latinoamerica_paises['date'], errors='coerce')
    data_latinoamerica_paises.set_index('date', inplace=True)
else:
    print("No se encontró la columna 'date'. Verifica que esté presente en el DataFrame.")

# Filtrar datos desde 2021
data_2021 = data_latinoamerica_paises.loc['2021-01-01':]

plt.figure(figsize=(14, 7))
sns.lineplot(data=data_2021.resample('M').mean(numeric_only=True), x='date', y='active_cases', label='Casos Activos')
sns.lineplot(data=data_2021.resample('M').mean(numeric_only=True), x='date', y='cumulative_recovered', label='Casos Recuperados')
plt.xlabel('Fecha')
plt.ylabel('Número de Casos')
plt.title('Evolución de Casos Activos vs. Recuperados en América Latina')
plt.legend()
plt.show()
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_9900\1949946686.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_latinoamerica_paises['active_cases'] = data_latinoamerica_paises['cumulative_confirmed'] - data_latinoamerica_paises['cumulative_deceased'] - data_latinoamerica_paises['cumulative_recovered']
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_9900\1949946686.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_latinoamerica_paises['date'] = pd.to_datetime(data_latinoamerica_paises['date'], errors='coerce')
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_9900\1949946686.py:15: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   sns.lineplot(data=data_2021.resample('M').mean(numeric_only=True), x='date', y='active_cases', label='Casos Activos')
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_9900\1949946686.py:16: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   sns.lineplot(data=data_2021.resample('M').mean(numeric_only=True), x='date', y='cumulative_recovered', label='Casos Recuperados')
